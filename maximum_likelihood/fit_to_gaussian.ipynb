# %%
#!/usr/bin/env python

# %%
import numpy as np
from scipy.stats import norm
from numpy import genfromtxt
import matplotlib.pyplot as plt

# %% [markdown]
# Having μ, σ tells us $p(x) = \frac{1}{\sigma \sqrt{2 \pi}} e^{-\frac{(x - \mu)^2}{2 \sigma^2}}$

# %%
X = genfromtxt('SAT.csv', delimiter=',')
μ = np.mean(X)
σ = np.std(X)

# %% [markdown]
# Plot the histogram of the data

# %%
plt.hist(X, bins=40, density=True, color='skyblue', edgecolor='black');

# %% [markdown]
# Plot the probability density function (PDF) of the normal distribution

# %%
x = np.linspace(μ - 4 * σ, μ+ 4 * σ, 100)
y = 1 / (σ * np.sqrt(2 * np.pi)) * np.exp(-(x - μ)**2 / (2 * σ**2))
plt.plot(x, y, color='red', linewidth=2)
plt.show()

# %% [markdown]
#  Set plot title and labels<br>
# lt.title('Normal Distribution')<br>
# lt.xlabel('Data')<br>
# lt.ylabel('Probability Density')<br>
# <br>
#  Display the plot<br>
# lt.show()<br>
# <br>
# <br>
# 	you can also obtain the specific value at certin point<br>
# 1 = norm.pdf(0)<br>
# rint(v1)<br>
# <br>
# 	you can also obtain the integral with cdf with the norm function<br>
# 2 = norm.cdf(0)<br>
# rint(v2)
